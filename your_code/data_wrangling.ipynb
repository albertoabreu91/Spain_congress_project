# %%
import pandas as pd
import numpy as np

# %%
# Importin Origin table spanish_regions.csv

spanish_regions = pd.read_csv('../spanishregions_dataset.csv', sep=';')

# %%
# Changing the name of "La Vall de Boí" to "Vall de Boí " to have the same name as in the muni_table shown next"

spanish_regions.loc[3847, 'RegionName'] = 'Vall de Boí'

# %%
spanish_regions.head()
# Out:
#    Code        RegionName  Population  TotalCensus  TotalVotes  \
# 0  1001  Alegría-Dulantzi        2882         1979        1339
# 1  1002           Amurrio       10263         8124        5722
# 2  1003           Aramaio        1518         1190         782
# 3  1004        Artziniega        1829         1399        1008
# 4  1006           Armiñón         244          175         140
#
#    AbstentionPtge  BlankVotesPtge  NullVotesPtge  PP_Ptge  PSOE_Ptge  ...  \
# 0          32.340           0.523          1.568   11.949     15.310  ...
# 1          29.567           0.542          1.188    8.668     10.346  ...
# 2          34.286           0.256          1.023    1.662      1.535  ...
# 3          27.949           0.794          1.290   12.897      7.044  ...
# 4          20.000           0.000          0.000   25.714     12.857  ...
#
#    Unemploy25_40_Ptge  UnemployMore40_Ptge  UnemployLess25_population_Ptge  \
# ...

# %%
spanish_regions[spanish_regions['RegionName'] == 'Vall de Boí']
# Out:
#        Code   RegionName  Population  TotalCensus  TotalVotes  AbstentionPtge  \
# 3847  25043  Vall de Boí        1004          807         501          37.918
#
#       BlankVotesPtge  NullVotesPtge  PP_Ptge  PSOE_Ptge  ...  \
# 3847           2.196          0.798    3.992      7.984  ...
#
#       Unemploy25_40_Ptge  UnemployMore40_Ptge  UnemployLess25_population_Ptge  \
# 3847                50.0                 50.0                             0.0
#
#       Unemploy25_40_population_Ptge  UnemployMore40_population_Ptge  \
# 3847                          0.498                           0.498
#
#       AgricultureUnemploymentPtge  IndustryUnemploymentPtge  \
# 3847                          0.0                      20.0
#
#       ConstructionUnemploymentPtge  ServicesUnemploymentPtge  \
# 3847                           0.0                      80.0
#
#       NotJobBeforeUnemploymentPtge
# 3847                           0.0
#
# [1 rows x 52 columns]

# %% [markdown]
# ## Importing the muni_table data containing information about municipalities in Catalonia

# %%
muni_table = pd.read_csv('../muni_table.csv')

# %%
muni_table.head()
# Out:
#          Municipality         Comarca   Province Population(2014)[3]  \
# 0  Abella de la Conca   Pallars Jussà     Lleida                 170
# 1              Abrera  Baix Llobregat  Barcelona              12,125
# 2                Àger         Noguera     Lleida                 594
# 3            Agramunt          Urgell     Lleida               5,515
# 4  Aguilar de Segarra           Bages  Barcelona                 251
#
#   Area(km2)[3] Density  No. ofEMDs[4]
# 0         78.3     2.2            NaN
# 1         19.9   609.3            NaN
# 2        160.6     3.7            NaN
# 3         79.6    69.3            NaN
# 4         43.3     5.8            NaN

# %%
# Changing the name of the Municipality column

muni_table = muni_table.rename(columns= {'Municipality': 'RegionName'})
muni_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 948 entries, 0 to 947
# Data columns (total 7 columns):
# RegionName             948 non-null object
# Comarca                947 non-null object
# Province               947 non-null object
# Population(2014)[3]    948 non-null object
# Area(km2)[3]           948 non-null object
# Density                948 non-null object
# No. ofEMDs[4]          41 non-null float64
# dtypes: float64(1), object(6)
# memory usage: 51.9+ KB

# %%
muni_table = muni_table[['Province', 'RegionName']][:-1]

# %%
muni_table.sort_values(['Province', 'RegionName']).head()
# Out:
#      Province          RegionName
# 1   Barcelona              Abrera
# 4   Barcelona  Aguilar de Segarra
# 6   Barcelona          Aiguafreda
# 28  Barcelona              Alella
# 43  Barcelona              Alpens

# %% [markdown]
# #### Joining the two tables spanish_regions and muni_table to see if they have repeated RegionNames

# %%
join_tables = spanish_regions.merge(muni_table, how= 'right')

# %%
join_tables[join_tables['RegionName'] == 'Vall de Boí']
# Out:
#       Code   RegionName  Population  TotalCensus  TotalVotes  AbstentionPtge  \
# 574  25043  Vall de Boí        1004          807         501          37.918
#
#      BlankVotesPtge  NullVotesPtge  PP_Ptge  PSOE_Ptge  ...  \
# 574           2.196          0.798    3.992      7.984  ...
#
#      UnemployMore40_Ptge  UnemployLess25_population_Ptge  \
# 574                 50.0                             0.0
#
#      Unemploy25_40_population_Ptge  UnemployMore40_population_Ptge  \
# 574                          0.498                           0.498
#
#      AgricultureUnemploymentPtge  IndustryUnemploymentPtge  \
# 574                          0.0                      20.0
#
#      ConstructionUnemploymentPtge  ServicesUnemploymentPtge  \
# 574                           0.0                      80.0
#
#      NotJobBeforeUnemploymentPtge  Province
# 574                           0.0    Lleida
#
# [1 rows x 53 columns]

# %%
join_tables[join_tables['RegionName'].duplicated()]
# Out:
#       Code RegionName  Population  TotalCensus  TotalVotes  AbstentionPtge  \
# 312  17030    Cabanes         931          641         400          37.598
# 411  33037     Mieres       40338        34455       22881          33.592
# 497  46244    Torrent       80107        58771       42137          28.303
# 767  43085   El Molar         291          226         180          20.354
#
#      BlankVotesPtge  NullVotesPtge  PP_Ptge  PSOE_Ptge  ...  \
# 312           0.250          0.500   15.500      8.500  ...
# 411           1.062          1.289   24.815     27.752  ...
# 497           0.641          0.641   34.117     21.777  ...
# 767           0.556          0.000    6.667     16.111  ...
#
#      UnemployMore40_Ptge  UnemployLess25_population_Ptge  \
# 312               46.939                           0.322
# 411               43.537                           0.739
# 497               48.443                           0.908
# ...

# %%
join_tables[join_tables['RegionName'] == 'Cabanes']
# Out:
#       Code RegionName  Population  TotalCensus  TotalVotes  AbstentionPtge  \
# 311  12033    Cabanes        2939         1919        1437          25.117
# 312  17030    Cabanes         931          641         400          37.598
#
#      BlankVotesPtge  NullVotesPtge  PP_Ptge  PSOE_Ptge  ...  \
# 311           1.322          2.296   37.161     24.635  ...
# 312           0.250          0.500   15.500      8.500  ...
#
#      UnemployMore40_Ptge  UnemployLess25_population_Ptge  \
# 311               45.641                           0.544
# 312               46.939                           0.322
#
#      Unemploy25_40_population_Ptge  UnemployMore40_population_Ptge  \
# 311                          3.062                           3.028
# 312                          2.470                           2.470
#
#      AgricultureUnemploymentPtge  IndustryUnemploymentPtge  \
# 311                        8.718                    18.974
# ...

# %%
spanish_regions[spanish_regions['RegionName'] == 'Cabanes']
# Out:
#        Code RegionName  Population  TotalCensus  TotalVotes  AbstentionPtge  \
# 1838  12033    Cabanes        2939         1919        1437          25.117
# 2480  17030    Cabanes         931          641         400          37.598
#
#       BlankVotesPtge  NullVotesPtge  PP_Ptge  PSOE_Ptge  ...  \
# 1838           1.322          2.296   37.161     24.635  ...
# 2480           0.250          0.500   15.500      8.500  ...
#
#       Unemploy25_40_Ptge  UnemployMore40_Ptge  UnemployLess25_population_Ptge  \
# 1838              46.154               45.641                           0.544
# 2480              46.939               46.939                           0.322
#
#       Unemploy25_40_population_Ptge  UnemployMore40_population_Ptge  \
# 1838                          3.062                           3.028
# 2480                          2.470                           2.470
#
#       AgricultureUnemploymentPtge  IndustryUnemploymentPtge  \
# ...

# %%
spanish_regions[spanish_regions['RegionName'] == 'Mieres']
# Out:
#        Code RegionName  Population  TotalCensus  TotalVotes  AbstentionPtge  \
# 2550  17105     Mieres         330          247         147          40.486
# 5005  33037     Mieres       40338        34455       22881          33.592
#
#       BlankVotesPtge  NullVotesPtge  PP_Ptge  PSOE_Ptge  ...  \
# 2550           0.680          0.000    8.844      3.401  ...
# 5005           1.062          1.289   24.815     27.752  ...
#
#       Unemploy25_40_Ptge  UnemployMore40_Ptge  UnemployLess25_population_Ptge  \
# 2550              38.462               53.846                           0.303
# 5005              48.835               43.537                           0.739
#
#       Unemploy25_40_population_Ptge  UnemployMore40_population_Ptge  \
# 2550                          1.515                           2.121
# 5005                          4.730                           4.217
#
#       AgricultureUnemploymentPtge  IndustryUnemploymentPtge  \
# ...

# %%
spanish_regions[spanish_regions['RegionName'] == 'Torrent']
# Out:
#        Code RegionName  Population  TotalCensus  TotalVotes  AbstentionPtge  \
# 2635  17197    Torrent         169          132         102          22.727
# 7216  46244    Torrent       80107        58771       42137          28.303
#
#       BlankVotesPtge  NullVotesPtge  PP_Ptge  PSOE_Ptge  ...  \
# 2635           0.980          0.980    5.882      8.824  ...
# 7216           0.641          0.641   34.117     21.777  ...
#
#       Unemploy25_40_Ptge  UnemployMore40_Ptge  UnemployLess25_population_Ptge  \
# 2635               50.00               50.000                           0.000
# 7216               43.17               48.443                           0.908
#
#       Unemploy25_40_population_Ptge  UnemployMore40_population_Ptge  \
# 2635                          0.592                           0.592
# 7216                          4.671                           5.242
#
#       AgricultureUnemploymentPtge  IndustryUnemploymentPtge  \
# ...

# %%
spanish_regions[spanish_regions['RegionName'] == 'El Molar']
# Out:
#        Code RegionName  Population  TotalCensus  TotalVotes  AbstentionPtge  \
# 4363  28086   El Molar        8036         5154        3530          31.510
# 6433  43085   El Molar         291          226         180          20.354
#
#       BlankVotesPtge  NullVotesPtge  PP_Ptge  PSOE_Ptge  ...  \
# 4363           0.368          1.048   41.190     18.470  ...
# 6433           0.556          0.000    6.667     16.111  ...
#
#       Unemploy25_40_Ptge  UnemployMore40_Ptge  UnemployLess25_population_Ptge  \
# 4363              49.664               45.470                           0.361
# 6433              33.333               66.667                           0.000
#
#       Unemploy25_40_population_Ptge  UnemployMore40_population_Ptge  \
# 4363                          3.683                           3.372
# 6433                          0.344                           0.687
#
#       AgricultureUnemploymentPtge  IndustryUnemploymentPtge  \
# ...

# %% [markdown]
# ###### Now that we know what municipalities are from Catalonia and which are not, we can delete them from the spanish_table to join this one with muni_table using RegionName as keys.

# %%
# Deleting Cabanes and creating a new table called final_spanish_regions

final_spanish_regions = spanish_regions.drop(1838)

# %%
## Just cheking if it was properly deleted

final_spanish_regions[final_spanish_regions['RegionName'] == 'Cabanes']
# Out:
#        Code RegionName  Population  TotalCensus  TotalVotes  AbstentionPtge  \
# 2480  17030    Cabanes         931          641         400          37.598
#
#       BlankVotesPtge  NullVotesPtge  PP_Ptge  PSOE_Ptge  ...  \
# 2480            0.25            0.5     15.5        8.5  ...
#
#       Unemploy25_40_Ptge  UnemployMore40_Ptge  UnemployLess25_population_Ptge  \
# 2480              46.939               46.939                           0.322
#
#       Unemploy25_40_population_Ptge  UnemployMore40_population_Ptge  \
# 2480                           2.47                            2.47
#
#       AgricultureUnemploymentPtge  IndustryUnemploymentPtge  \
# 2480                       10.204                     2.041
#
#       ConstructionUnemploymentPtge  ServicesUnemploymentPtge  \
# 2480                        10.204                    65.306
#
#       NotJobBeforeUnemploymentPtge
# 2480                        12.245
#
# [1 rows x 52 columns]

# %%
# Deleting Mieres

final_spanish_regions = final_spanish_regions.drop(5005)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-ee05dac6e625> in <module>
#       1 # Deleting Mieres
#       2
# ----> 3 final_spanish_regions = final_spanish_regions.drop(5005)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
## Just cheking if it was properly deleted

final_spanish_regions[final_spanish_regions['RegionName'] == 'Mieres']
# Out:
#        Code RegionName  Population  TotalCensus  TotalVotes  AbstentionPtge  \
# 2550  17105     Mieres         330          247         147          40.486
#
#       BlankVotesPtge  NullVotesPtge  PP_Ptge  PSOE_Ptge  ...  \
# 2550            0.68            0.0    8.844      3.401  ...
#
#       Unemploy25_40_Ptge  UnemployMore40_Ptge  UnemployLess25_population_Ptge  \
# 2550              38.462               53.846                           0.303
#
#       Unemploy25_40_population_Ptge  UnemployMore40_population_Ptge  \
# 2550                          1.515                           2.121
#
#       AgricultureUnemploymentPtge  IndustryUnemploymentPtge  \
# 2550                          0.0                       0.0
#
#       ConstructionUnemploymentPtge  ServicesUnemploymentPtge  \
# 2550                         7.692                    84.615
#
#       NotJobBeforeUnemploymentPtge
# 2550                         7.692
#
# [1 rows x 52 columns]

# %%
# Deleting Torrent

final_spanish_regions = final_spanish_regions.drop(7216)

# %%
## Just cheking if it was properly deleted

final_spanish_regions[final_spanish_regions['RegionName'] == 'Torrent']
# Out:
#        Code RegionName  Population  TotalCensus  TotalVotes  AbstentionPtge  \
# 2635  17197    Torrent         169          132         102          22.727
#
#       BlankVotesPtge  NullVotesPtge  PP_Ptge  PSOE_Ptge  ...  \
# 2635            0.98           0.98    5.882      8.824  ...
#
#       Unemploy25_40_Ptge  UnemployMore40_Ptge  UnemployLess25_population_Ptge  \
# 2635                50.0                 50.0                             0.0
#
#       Unemploy25_40_population_Ptge  UnemployMore40_population_Ptge  \
# 2635                          0.592                           0.592
#
#       AgricultureUnemploymentPtge  IndustryUnemploymentPtge  \
# 2635                          0.0                       0.0
#
#       ConstructionUnemploymentPtge  ServicesUnemploymentPtge  \
# 2635                          50.0                      50.0
#
#       NotJobBeforeUnemploymentPtge
# 2635                           0.0
#
# [1 rows x 52 columns]

# %%
# Deleting El Molar

final_spanish_regions = final_spanish_regions.drop(4363)

# %%
## Just cheking if it was properly deleted

final_spanish_regions[final_spanish_regions['RegionName'] == 'El Molar']
# Out:
#        Code RegionName  Population  TotalCensus  TotalVotes  AbstentionPtge  \
# 6433  43085   El Molar         291          226         180          20.354
#
#       BlankVotesPtge  NullVotesPtge  PP_Ptge  PSOE_Ptge  ...  \
# 6433           0.556            0.0    6.667     16.111  ...
#
#       Unemploy25_40_Ptge  UnemployMore40_Ptge  UnemployLess25_population_Ptge  \
# 6433              33.333               66.667                             0.0
#
#       Unemploy25_40_population_Ptge  UnemployMore40_population_Ptge  \
# 6433                          0.344                           0.687
#
#       AgricultureUnemploymentPtge  IndustryUnemploymentPtge  \
# 6433                          0.0                    66.667
#
#       ConstructionUnemploymentPtge  ServicesUnemploymentPtge  \
# 6433                           0.0                    33.333
#
#       NotJobBeforeUnemploymentPtge
# 6433                           0.0
#
# [1 rows x 52 columns]

# %%
# Saving the new table to a csv file

# %%
final_spanish_regions.to_csv('final_spanish_regions.csv')

# %%
final_spanish_regions
# Out:
#        Code                      RegionName  Population  TotalCensus  \
# 0      1001                Alegría-Dulantzi        2882         1979
# 1      1002                         Amurrio       10263         8124
# 2      1003                         Aramaio        1518         1190
# 3      1004                      Artziniega        1829         1399
# 4      1006                         Armiñón         244          175
# 5      1008             Arratzua-Ubarrundia         997          786
# 6      1009                       Asparrena        1647         1265
# 7      1010                   Ayala / Aiara        2927         2268
# 8      1011         Baños de Ebro / Mañueta         311          235
# 9      1013                       Barrundia         905          712
# 10     1014                    Berantevilla         467          371
# 11     1016                         Bernedo         526          433
# 12     1017               Campezo / Kanpezu        1069          849
# ...

# %%
muni_table.to_csv('../muni_table.csv')
